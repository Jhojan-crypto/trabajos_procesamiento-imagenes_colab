# %%
a=5
b=4
print(a+b)
# Out:
# 9

# %%
def function1():
  print('Hola Mundo')
function1()
# Out:
# Hola Mundo

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive
# Out:
# /content/drive

# %%
# !ls -l
# Out:
# total 4
# drwx------ 16 root root 4096 May 23 01:39 MyDrive

# %%
# %cd My Drive
# Out:
# /content/drive/My Drive

# %%
import matplotlib.pyplot as pylot

# %%
x=[1,2,3,4,5,6,7,8,9]

# %%
y1=[1,3,5,8,1,2,6,3,1]
y2=[2,1,6,2,2,3,6,4,2]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y1,label='A')

# %%
plt.plot(x,y2,label='B')

# %%
plt.plot()
# Out:
# []

# %%
plt.xlabel('X')
# Out:
# Text(0.5, 0, 'X')

# %%
plt.plot(x,y1,label='A')
plt.plot(x,y2,label='B')
plt.plot()

plt.xlabel('en el eje X')
plt.xlabel('en el eje Y')
plt.legend()
plt.show()

# %%
plt.plot(x,y1,label='A')
plt.plot(x,y2,label='B')
plt.plot()

plt.xlabel('en el eje X')
plt.ylabel('en el eje Y')
plt.legend()
plt.show()

# %%
from google.colab import files
files.upload()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
files.download('/content/drive/MyDrive/gata_mini.jpeg')

# %%
import time

# %%
print(time.ctime())
# Out:
# Tue May 23 02:01:01 2023

# %% [markdown]
# Eliminar Celda

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
y=np.random.randn(100)
x=[x for x in range(len(y))]
plt.plot(x,y,'-')
plt.fill_between(x,y,200,where=(y>195),facecolor='g', alpha=0.6)
plt.title("Sample Plot")
plt.show()

# %% [markdown]
# **Listado de Dispositivos**

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices
# Out:
# <function tensorflow.python.client.device_lib.list_local_devices(session_config=None)>

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13294264 kB
# MemFree:         8564180 kB
# MemAvailable:   11828696 kB
# Buffers:          325772 kB
# Cached:          3125516 kB
# SwapCached:            0 kB
# Active:           693964 kB
# Inactive:        3788064 kB
# Active(anon):       1136 kB
# Inactive(anon):  1031144 kB
# Active(file):     692828 kB
# Inactive(file):  2756920 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               640 kB
# Writeback:             0 kB
# AnonPages:       1022012 kB
# Mapped:           544672 kB
# Shmem:              1408 kB
# KReclaimable:     111448 kB
# Slab:             148180 kB
# SReclaimable:     111448 kB
# SUnreclaim:        36732 kB
# KernelStack:        5536 kB
# PageTables:        18340 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6647132 kB
# Committed_AS:    3118828 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:       10500 kB
# VmallocChunk:          0 kB
# Percpu:             1312 kB
# HardwareCorrupted:     0 kB
# AnonHugePages:     36864 kB
# ShmemHugePages:        0 kB
# ShmemPmdMapped:        0 kB
# FileHugePages:         0 kB
# FilePmdMapped:         0 kB
# CmaTotal:              0 kB
# CmaFree:               0 kB
# HugePages_Total:       0
# HugePages_Free:        0
# HugePages_Rsvd:        0
# HugePages_Surp:        0
# Hugepagesize:       2048 kB
# Hugetlb:               0 kB
# DirectMap4k:       90936 kB
# DirectMap2M:     5148672 kB
# DirectMap1G:    10485760 kB
